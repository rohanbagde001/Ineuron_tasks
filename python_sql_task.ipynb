# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',password='@Born2Ride')

# %%
cursor=mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('breast_cancer',),
#  ('classicmodels',),
#  ('customer',),
#  ('fun',),
#  ('ineuron',),
#  ('ineuron1',),
#  ('ineuron_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('org',),
#  ('performance_schema',),
#  ('rohan12345',),
#  ('sakila',),
#  ('sudhanshu12345',),
#  ('sys',),
#  ('test12345',),
#  ('world',)]

# %%
cursor.execute('create database cardataset') # we created car datase

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('create table cardataset.car(Price varchar(20), Maintaiace varchar(20),Doors varchar(20),Persons varchar(20),Luggage_boot varchar(20), Safety varchar(20), Class varchar(20))')

# %%
#cursor.execute('drop database CARDATASET')

# %%
#mydb.commit()

# %%
cursor.execute('use cardataset')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()  # we created table car
# Out:
# [('car',)]

# %%
sql = "INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s)"

# %%
import csv 
with open('car.data','r') as f:        #Dump all the data into database
    car_data = csv.reader(f,delimiter = '\n')
    for i in car_data:
        val = tuple(i[0].split(','))
        print(sql,val)
        cursor.execute(sql,val)
# Out:
# INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s) ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')
# INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s) ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc')
# INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s) ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc')
# INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s) ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc')
# INSERT INTO cardataset.car(Price, Maintaiace,Doors,Persons,Luggage_boot,Safety,Class) VALUES (%s, %s, %s, %s, %s, %s,%s) ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc')
# ...

# %%
mydb.commit()

# %%
# check all the data is available or not

# %%
cursor.execute('select count(*) from cardataset.car')

# %%
cursor.fetchall()
# Out:
# [(1728,)]

# %%
# Try to group all the data with Col1 and count occurence of each and every record based on col1 value

# %%
cursor.execute('select Price,count(*) from cardataset.car group by Price')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
cursor.execute('select Maintaiace,count(*) from cardataset.car group by Maintaiace')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
# Try to filter a record where column 3 value will be 4

# %%
cursor.execute('select Doors from cardataset.car where Doors=4')

# %%
cursor.fetchall()
# Out:
# [('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
#  ('4',),
# ...

# %%
# Try to update a column3 value with 8 wherever you have equal to 2

# %%
cursor.execute('select count(Doors) from cardataset.car where Doors=2')

# %%
cursor.fetchall()
# Out:
# [(432,)]

# %%
cursor.execute('update cardataset.car set Doors = "8" where Doors = "2"')

# %%
mydb.commit()

# %%
cursor.execute('select count(Doors) from cardataset.car where Doors = 8')

# %%
cursor.fetchall()
# Out:
# [(432,)]

# %%
# Delete the table

# %%
cursor.execute('drop table cardataset.car')
mydb.commit()

# %%
# checking it is dropped or not

# %%
cursor.execute('desc cardataset.car')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'cardataset.car' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-78-a23177d9675c> in <module>
# ----> 1 cursor.execute('desc cardataset.car')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
# ...

# %%
# Delete the DAtabase

# %%
cursor.execute('drop database cardataset')

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('breast_cancer',),
#  ('classicmodels',),
#  ('customer',),
#  ('fun',),
#  ('ineuron',),
#  ('ineuron1',),
#  ('ineuron_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('org',),
#  ('performance_schema',),
#  ('rohan12345',),
#  ('sakila',),
#  ('sudhanshu12345',),
#  ('sys',),
#  ('test12345',),
#  ('world',)]
